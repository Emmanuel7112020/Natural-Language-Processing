# %% [markdown]
# ### Installing Required Libraries

# %%
# !pip install pandas

# Library needed to read the PDF file containing conference proceedings
#!pip install textract
# !pip install PyPDF2

# Library required for topic modeling
# !pip install bertopic

# Library needed for text pre-processing
# !pip install nltk

# %% [markdown]
# ### Importing Required Libraries

# %%
import pandas as pd

# Importing Packages
#import textract

# Importing function to read PDF file contents
from PyPDF2 import PdfFileReader

# Importing packages for topic modelling and removing stop words
from bertopic import BERTopic
from sklearn.feature_extraction.text import CountVectorizer

import nltk
nltk.download('all')
from nltk.tokenize import word_tokenize, sent_tokenize

# %%
# Setting pandas dataframe display option for rows
pd.options.display.max_rows = 400

# %% [markdown]
# ### Reading the Input File (PDF File) and Extracting Text

# %%
#text =textract.process('INFORMS_2022.pdf', method='pdfminer')
#text_str= str(text)
# consider chamging 'rb' to 'r'

filename = 'INFORMS_2022.pdf'
pdfFileObj = open(filename,'rb')
pdfReader = PdfFileReader(pdfFileObj,strict=False)

num_pages = pdfReader.numPages 
print(num_pages)


count = 0
text = '''  '''

# Creation of loop to read all pages of the PDF file
while count < num_pages:
    pageObj = pdfReader.getPage(count)
    count +=1
    text += pageObj.extractText()
# Out:
# 1072

# %% [markdown]
# ### Text Preprocessing- Removal of Stop Words

# %%
# Performing Sentence Tokenization
tokens= sent_tokenize(text)
type(tokens)
#len(tokens)

# Step to remove stop words
vectorizer_model = CountVectorizer(stop_words="english")

# %% [markdown]
# ### Topic Modeling- Training of Topic Model

# %%
# Training the Model;  'calculate_probabilities=True' calculates the probabilities of all topics in a document
#topic_model = BERTopic(language="english", calculate_probabilities=True)  
# nr_topics="auto" does automatic reduction of topics generated

#"topics" contains a one-to-one mapping of inputs to their modeled topic (or cluster).
#"probs" contains a list of probabilities that an input belongs to their assigned topic.

topic_model = BERTopic(vectorizer_model=vectorizer_model, nr_topics="auto", calculate_probabilities=True)

# Alternatively
#topic_model = BERTopic(nr_topics="auto", calculate_probabilities=True)

topics, probs = topic_model.fit_transform(tokens)

# %%
print(topics,probs)

# %% [markdown]
# ### Extraction of Topics From The Model

# %%
# To access topics generated based on their relative frequency
topic_model.get_topic_freq()
# Out:
#      Topic  Count
# 0       -1  11209
# 1        0   7955
# 2        1    167
# 3        2    157
# 4        3    150
# 5        4    146
# 6        5    137
# 7        6    137
# 8        7    132
# 9        8    130
# 10       9    120
# 11      10    113
# 12      11    104
# 13      12    102
# 14      13    101
# 16      14     97
# 15      15     97
# 17      16     93
# 18      17     91
# 19      18     91
# 20      19     88
# 21      20     83
# 22      21     82
# 23      22     82
# 24      23     77
# 25      24     76
# 26      25     76
# 27      26     76
# 28      27     76
# 30      28     74
# 29      29     74
# 31      30     70
# 32      31     69
# 33      32     60
# 34      33     58
# 35      34     58
# 36      35     57
# 37      36     56
# 38      37     55
# 39      38     54
# 40      39     54
# 41      40     53
# 42      41     52
# 43      42     51
# 44      43     50
# 45      44     49
# 46      45     46
# 47      46     42
# 48      47     42
# 49      48     42
# 50      49     39
# 51      50     39
# 52      51     38
# 53      52     37
# 54      53     37
# 55      54     36
# 56      55     36
# 58      58     35
# 59      56     35
# 57      57     35
# 62      60     34
# 60      61     34
# 61      59     34
# 63      62     31
# 64      63     30
# 65      64     30
# 66      65     30
# 67      66     30
# 68      67     30
# 71      69     29
# 72      68     29
# 70      71     29
# 69      70     29
# 73      72     27
# 75      73     26
# 74      74     26
# 76      75     25
# 77      76     25
# 78      77     25
# 79      78     24
# 80      79     24
# 81      80     21
# 82      81     20
# 83      82     20
# 87      85     19
# 89      84     19
# 88      83     19
# 86      87     19
# 84      86     19
# 85      88     19
# 90      89     18
# 91      90     18
# 92      91     18
# 93      92     17
# 94      93     16
# 95      94     16
# 96      95     16
# 97      96     15
# 100    101     14
# 101     98     14
# 102     97     14
# 99     100     14
# 98      99     14
# 103    102     13
# 104    103     13
# 105    104     13
# 106    105     13
# 107    106     13
# 111    109     12
# 112    107     12
# 109    111     12
# 110    108     12
# 108    110     12
# 113    112     11
# 114    113     11
# 115    114     10
# 116    115     10
# 117    116     10

# %%
# Viewing the Topics
#After generating topics and their probabilities, we can access the frequent topics that were generated; -1 refers to all outliers (documents that couldn't be clustered) and should typically be ignored.
# "count" refers to the number of documents per topic
# "name"comprises topic id and words that are best representative of the cluster of the topic
topic_model.get_topic_info()
# Out:
#      Topic  Count                                               Name
# 0       -1  11209                  -1_university_model_data_learning
# 1        0   7955               0_university_session_contact_problem
# 2        1    167           1_integer_mixedinteger_programming_mixed
# 3        2    157   2_privacy_differential_private_privacypreserving
# 4        3    150  3_blockchain_cryptocurrency_cryptocurrencies_m...
# 5        4    146         4_crowdfunding_donors_fundraising_donation
# 6        5    137                 5_quantum_qubo_computing_annealing
# 7        6    137                   6_fairness_fair_notions_measures
# 8        7    132                      7_drone_drones_delivery_truck
# 9        8    130             8_bandit_bandits_contextual_multiarmed
# 10       9    120                          9_workers_wage_worker_gig
# 11      10    113                 10_farmers_yield_agricultural_crop
# 12      11    104                        11_reviews_review_online_aw
# 13      12    102       12_convergence_estimator_approximation_error
# 14      13    101            13_vaccine_vaccination_vaccines_covid19
# 15      14     97                        14_carbon_co2_emissions_ccs
# 16      15     97                         15_train_rail_trains_dwell
# 17      16     93                    16_auctions_auction_bidding_bid
# 18      17     91  17_recommendation_recommender_recommendations_...
# 19      18     91          18_platforms_platform_sellers_multihoming
# 20      19     88  19_contact_tabishiitk_yunduanlinberkeley_lough...
# 21      20     83         20_heuristics_heuristic_instances_solution
# 22      21     82                 21_portfolio_returns_stock_trading
# 23      22     82        22_environmental_sustainability_green_firms
# 24      23     77          23_policy_policies_optimal_asymptotically
# 25      24     76                   24_organ_transplant_kidney_liver
# 26      25     76                  25_hydrogen_h2_energy_electricity
# 27      26     76         26_simulation_simulations_simulated_method
# 28      27     76                27_wildfire_wildfires_ignition_fuel
# 29      28     74               28_matching_match_matches_pigeonhole
# 30      29     74                  29_benders_decomposition_cuts_cut
# 31      30     70               30_defender_attacker_attack_security
# 32      31     69              31_causal_treatment_inference_effects
# 33      32     60              32_opioid_overdose_epidemic_overdoses
# 34      33     58           33_telehealth_telemedicine_care_inperson
# 35      34     58      34_forecasts_forecast_forecasting_forecasters
# 36      35     57                     35_graph_graphs_maximum_clique
# 37      36     56                    36_trees_tree_rashomon_decision
# 38      37     55        37_anomaly_detection_unsupervised_anomalies
# 39      38     54             38_matrix_lowrank_factorization_sparse
# 40      39     54            39_facility_location_facilities_problem
# 41      40     53                       40_advertising_ad_screen_ads
# 42      41     52      41_fitradeoff_multicriteria_pernambuco_recife
# 43      42     51      42_interventions_intervention_funding_welfare
# 44      43     50              43_clustering_clusters_cluster_points
# 45      44     49                    44_police_crime_policing_patrol
# 46      45     46             45_tensor_tensors_embedding_completion
# 47      46     42             46_convergence_fw_iteration_iterations
# 48      47     42            47_adversarial_training_robustness_hbar
# 49      48     42                 48_contests_contest_seats_entrants
# 50      49     39                     49_wind_offshore_onshore_farms
# 51      50     39                         50_gaussian_gp_process_mgp
# 52      51     38               51_diabetes_maternal_adverse_alcohol
# 53      52     37          52_transparency_opaque_transparent_supply
# 54      53     37                53_spread_disease_epidemics_viruses
# 55      54     36              54_conservation_wildlife_species_fish
# 56      55     36       55_cyber_cybersecurity_cyberattacks_security
# 57      56     35                       56_music_artists_songs_audio
# 58      57     35           57_bilevel_optimization_inner_stochastic
# 59      58     35           58_cancer_radiation_radiotherapy_therapy
# 60      59     34               59_parking_curbspace_double_curbside
# 61      60     34                 60_weather_climate_seasonal_ignite
# 62      61     34        61_refugees_refugee_resettlement_relocation
# 63      62     31                  62_misinformation_news_rumor_fake
# 64      63     30                 63_loans_lending_borrowers_lenders
# 65      64     30                       64_nft_sale_nfts_nonfungible
# 66      65     30                          65_sepsis_icu_septic_icus
# 67      66     30               66_token_tokens_uniswap_tokenization
# 68      67     30         67_escooters_escooter_rebalancing_charging
# 69      68     29            68_imbalanced_imbalance_class_fairfield
# 70      69     29                       69_label_labels_labeling_snc
# 71      70     29              70_trafficking_sex_commercial_illicit
# 72      71     29              71_metrics_performance_metric_unitthe
# 73      72     27                        72_2022_annual_informs_2021
# 74      73     26      73_solar_forecasting_irradiance_probabilistic
# 75      74     26                   74_chatbot_chatbots_machines_bot
# 76      75     25                      75_gams_wabash_tutorial_taipy
# 77      76     25  76_exploration_exploitation_tradeoff_exploreth...
# 78      77     25               77_crowdsourcing_voters_wisdom_crowd
# 79      78     24                78_gan_generative_gans_augmentation
# 80      79     24                   79_cardiac_arrhythmias_ecg_heart
# 81      80     21                       80_vrp_solver_luxembourg_jsp
# 82      81     20                        81_census_vh_tract_cropland
# 83      82     20              82_federated_learning_multitask_arbor
# 84      83     19                  83_screening_mass_fibrosis_cystic
# 85      84     19                84_return_lenient_returns_retailers
# 86      85     19                  85_audits_audit_auditing_leniency
# 87      86     19                   86_bias_implicit_keywords_biases
# 88      87     19                           87_trust_dapps_dapp_gaze
# 89      88     19                88_recall_recalls_product_complaint
# 90      89     18               89_adherence_medication_treatment_tb
# 91      90     18      90_decentralized_queuing_multiagent_bipartite
# 92      91     18  91_remanufacturing_remanufactured_products_pro...
# 93      92     17      92_polynomials_polytope_projections_polytopes
# 94      93     16                  93_component_pca_principal_signal
# 95      94     16                     94_renters_lease_renter_buyout
# 96      95     16     95_generation_column_columnandconstraint_solve
# 97      96     15                    96_dea_envelopment_measure_sdea
# 98      97     14      97_drsubmodular_submodular_monotone_functions
# 99      98     14                      98_outage_power_outages_lines
# 100     99     14                       99_nphard_graphic_matroid_np
# 101    100     14                 100_mpc_control_predictive_platoon
# 102    101     14                       101_mip_righthand_sides_milp
# 103    102     13    102_physics_physicsinformed_equations_nonlinear
# 104    103     13    103_multiobjective_pareto_frontier_optimization
# 105    104     13                         104_joint_work_swati_gupta
# 106    105     13  105_stability_lyapunov_controllability_properties
# 107    106     13                     106_decoder_keys_rko_randomkey
# 108    107     12       107_microgrids_microgrid_advancing_networked
# 109    108     12       108_thresholds_threshold_sequence_continuity
# 110    109     12                         109_namnc_explain_deep_net
# 111    110     12           110_svm_costsensitive_ksmmfs_sensitivity
# 112    111     12          111_congestion_refunding_toll_externality
# 113    112     11  112_calibration_discrepancy_computer_linearreg...
# 114    113     11                   113_defect_inspection_chiao_tung
# 115    114     10          114_tierwise_bwe_amplification_intralayer
# 116    115     10  115_hyperparameters_tuning_hyperparameter_requ...
# 117    116     10               116_inverse_houra_kimia_observations

# %%
# Get top terms for specific topic
topic_model.get_topic(0)
# Out:
# [('university', 0.0072460775010985065),
#  ('session', 0.006575720406948091),
#  ('contact', 0.005764535929597535),
#  ('problem', 0.00530293632243474),
#  ('chair', 0.005236868976896552),
#  ('optimization', 0.00509061894460121),
#  ('model', 0.004972923962020461),
#  ('study', 0.004742708602807538),
#  ('data', 0.004734583959547473),
#  ('network', 0.004521650513822912)]

# %% [markdown]
# ### Visualization of Topics

# %%
#Visualizing Topics on Intertopic Distance Map
topic_model.visualize_topics()
# Out:
# <div>                            <div id="0def6073-efa8-490c-ada1-02cd7083c9aa" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0def6073-efa8-490c-ada1-02cd7083c9aa")) {                    Plotly.newPlot(                        "0def6073-efa8-490c-ada1-02cd7083c9aa",                        [{"customdata":[[0,"university | session | contact | problem | chair",7955],[1,"integer | mixedinteger | programming | mixed | linear",167],[2,"privacy | differential | private | privacypreserving | data",157],[3,"blockchain | cryptocurrency | cryptocurrencies | miners | bitcoin",150],[4,"crowdfunding | donors | fundraising | donation | donations",146],[5,"quantum | qubo | computing | annealing | optimization",137],[6,"fairness | fair | notions | measures | unfairness",137],[7,"drone | drones | delivery | truck | routing",132],[8,"bandit | bandits | contextual | multiarmed | thompson",130],[9,"workers | wage | worker | gig | skill",120],[10,"farmers | yield | agricultural | crop | agriculture",113],[11,"reviews | review | online | aw | fake",104],[12,"convergence | estimator | approximation | error | bound",102],[13,"vaccine | vaccination | vaccines | covid19 | allocation",101],[14,"carbon | co2 | emissions | ccs | capture",97],[15,"train | rail | trains | dwell | line",97],[16,"auctions | auction | bidding | bid | bidders",93],[17,"recommendation | recommender | recommendations | users | systems",91],[18,"platforms | platform | sellers | multihoming | service",91],[19,"contact | tabishiitk | yunduanlinberkeley | loughborough | martin",88],[20,"heuristics | heuristic | instances | solution | search",83],[21,"portfolio | returns | stock | trading | portfolios",82],[22,"environmental | sustainability | green | firms | sustainable",82],[23,"policy | policies | optimal | asymptotically | derive",77],[24,"organ | transplant | kidney | liver | transplantation",76],[25,"hydrogen | h2 | energy | electricity | electrolyzers",76],[26,"simulation | simulations | simulated | method | simulators",76],[27,"wildfire | wildfires | ignition | fuel | power",76],[28,"matching | match | matches | pigeonhole | markets",74],[29,"benders | decomposition | cuts | cut | cutting",74],[30,"defender | attacker | attack | security | attacks",70],[31,"causal | treatment | inference | effects | effect",69],[32,"opioid | overdose | epidemic | overdoses | pittsburgh",60],[33,"telehealth | telemedicine | care | inperson | healthcare",58],[34,"forecasts | forecast | forecasting | forecasters | earnings",58],[35,"graph | graphs | maximum | clique | matching",57],[36,"trees | tree | rashomon | decision | ensembles",56],[37,"anomaly | detection | unsupervised | anomalies | mississippi",55],[38,"matrix | lowrank | factorization | sparse | qr",54],[39,"facility | location | facilities | problem | obnoxious",54],[40,"advertising | ad | screen | ads | advertisers",53],[41,"fitradeoff | multicriteria | pernambuco | recife | brazil",52],[42,"interventions | intervention | funding | welfare | groups",51],[43,"clustering | clusters | cluster | points | kmeans",50],[44,"police | crime | policing | patrol | crimes",49],[45,"tensor | tensors | embedding | completion | reduction",46],[46,"convergence | fw | iteration | iterations | stepsize",42],[47,"adversarial | training | robustness | hbar | adversarially",42],[48,"contests | contest | seats | entrants | prize",42],[49,"wind | offshore | onshore | farms | maintenance",39],[50,"gaussian | gp | process | mgp | multioutput",39],[51,"diabetes | maternal | adverse | alcohol | prenatal",38],[52,"transparency | opaque | transparent | supply | products",37],[53,"spread | disease | epidemics | viruses | infectious",37],[54,"conservation | wildlife | species | fish | carp",36],[55,"cyber | cybersecurity | cybera ...

# %%
# Visualizing Optimal Number of Topics and Their Top 10 Constituent Keywords
topic_model.visualize_barchart(width=280, height=330,n_words=10, top_n_topics=107)
#topic_model.visualize_barchart(width=280, height=330, top_n_topics=10)
# Out:
# <div>                            <div id="038bca62-71c5-4108-8087-cc5b8653c9f1" class="plotly-graph-div" style="height:8910px; width:1120px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("038bca62-71c5-4108-8087-cc5b8653c9f1")) {                    Plotly.newPlot(                        "038bca62-71c5-4108-8087-cc5b8653c9f1",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.004521650513822912,0.004734583959547473,0.004742708602807538,0.004972923962020461,0.00509061894460121,0.005236868976896552,0.00530293632243474,0.005764535929597535,0.006575720406948091,0.0072460775010985065],"y":["network  ","data  ","study  ","model  ","optimization  ","chair  ","problem  ","contact  ","session  ","university  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.01955925030545084,0.02155809057559752,0.022391659441432565,0.023060893121822194,0.03549211453385688,0.0436400315448551,0.053685701800618484,0.0617231621913654,0.07161042223674528,0.07856501685950121],"y":["problem  ","formulated  ","programs  ","nonlinear  ","program  ","linear  ","mixed  ","programming  ","mixedinteger  ","integer  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.015498459819691621,0.015797077946891037,0.0167706696816426,0.023035515091719718,0.02369943978724059,0.027583101212845344,0.027630818182921943,0.030508825336939962,0.03699160459644087,0.15098337674024176],"y":["consumer  ","users  ","personal  ","concerns  ","information  ","data  ","privacypreserving  ","private  ","differential  ","privacy  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.
0.0],"xaxis":"x","y":[-185.0,-185.0,-195.0,-195.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","x":[0.0,1.3549069296367473,1.3549069296367473, ...

# %%
#Visualizing Topic Similarity (Determining which topics are related)
#topic_model.visualize_heatmap(n_clusters=20, width=1000, height=1000)
topic_model.visualize_heatmap()
# Out:
# <div>                            <div id="a19acd74-47da-4322-8bcd-9e51d04fb5bb" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a19acd74-47da-4322-8bcd-9e51d04fb5bb")) {                    Plotly.newPlot(                        "a19acd74-47da-4322-8bcd-9e51d04fb5bb",                        [{"coloraxis":"coloraxis","name":"0","x":["0_university_session_contact","1_integer_mixedinteger_prog...","2_privacy_differential_priv...","3_blockchain_cryptocurrency...","4_crowdfunding_donors_fundr...","5_quantum_qubo_computing","6_fairness_fair_notions","7_drone_drones_delivery","8_bandit_bandits_contextual","9_workers_wage_worker","10_farmers_yield_agricultural","11_reviews_review_online","12_convergence_estimator_ap...","13_vaccine_vaccination_vacc...","14_carbon_co2_emissions","15_train_rail_trains","16_auctions_auction_bidding","17_recommendation_recommend...","18_platforms_platform_sellers","19_contact_tabishiitk_yundu...","20_heuristics_heuristic_ins...","21_portfolio_returns_stock","22_environmental_sustainabi...","23_policy_policies_optimal","24_organ_transplant_kidney","25_hydrogen_h2_energy","26_simulation_simulations_s...","27_wildfire_wildfires_ignit...","28_matching_match_matches","29_benders_decomposition_cuts","30_defender_attacker_attack","31_causal_treatment_inference","32_opioid_overdose_epidemic","33_telehealth_telemedicine_...","34_forecasts_forecast_forec...","35_graph_graphs_maximum","36_trees_tree_rashomon","37_anomaly_detection_unsupe...","38_matrix_lowrank_factoriza...","39_facility_location_facili...","40_advertising_ad_screen","41_fitradeoff_multicriteria...","42_interventions_interventi...","43_clustering_clusters_clus...","44_police_crime_policing","45_tensor_tensors_embedding","46_convergence_fw_iteration","47_adversarial_training_rob...","48_contests_contest_seats","49_wind_offshore_onshore","50_gaussian_gp_process","51_diabetes_maternal_adverse","52_transparency_opaque_tran...","53_spread_disease_epidemics","54_conservation_wildlife_sp...","55_cyber_cybersecurity_cybe...","56_music_artists_songs","57_bilevel_optimization_inner","58_cancer_radiation_radioth...","59_parking_curbspace_double","60_weather_climate_seasonal","61_refugees_refugee_resettl...","62_misinformation_news_rumor","63_loans_lending_borrowers","64_nft_sale_nfts","65_sepsis_icu_septic","66_token_tokens_uniswap","67_escooters_escooter_rebal...","68_imbalanced_imbalance_class","69_label_labels_labeling","70_trafficking_sex_commercial","71_metrics_performance_metric","72_2022_annual_informs","73_solar_forecasting_irradi...","74_chatbot_chatbots_machines","75_gams_wabash_tutorial","76_exploration_exploitation...","77_crowdsourcing_voters_wis...","78_gan_generative_gans","79_cardiac_arrhythmias_ecg","80_vrp_solver_luxembourg","81_census_vh_tract","82_federated_learning_multi...","83_screening_mass_fibrosis","84_return_lenient_returns","85_audits_audit_auditing","86_bias_implicit_keywords","87_trust_dapps_dapp","88_recall_recalls_product","89_adherence_medication_tre...","90_decentralized_queuing_mu...","91_remanufacturing_remanufa...","92_polynomials_polytope_pro...","93_component_pca_principal","94_renters_lease_renter","95_generation_column_column...","96_dea_envelopment_measure","97_drsubmodular_submodular_...","98_outage_power_outages","99_nphard_graphic_matroid","100_mpc_control_